# %% [markdown]
# # Using MLP Classifier

# %% [markdown]
# Resources:
# https://analyticsindiamag.com/a-beginners-guide-to-scikit-learns-mlpclassifier/
# https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html

# %% [markdown]
# This version is more a test to understand how keras builds this system and how I can use it to solve the exercise.
#
# Current status: Only using the default values from keras, so no testing done on different parameters.

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd 
import datetime as dt
import os

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import TensorBoard

# %% [markdown]
# ### Read Data sets

# %%
train_data = pd.read_csv("../dataset/mnist_train.csv", header=None)

# %%
test_data = pd.read_csv("../dataset/mnist_test.csv", header=None)

# %% [markdown]
# ### Create sparse matrix of shape and classification for train and test data

# %%
num_classes = 10
batch_size = 128
epochs = 20

# %%
train_values = train_data.values[:,1:]/255
test_values = test_data.values[:,1:]/255

# %%
train_classes = keras.utils.to_categorical(train_data.values[:,0:1], num_classes)
test_classes = keras.utils.to_categorical(test_data.values[:,0:1], num_classes)

# %% [markdown]
# ## Use MLP Classifier

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
logir = '.\logs\\'

# %%
tensorboard = TensorBoard(log_dir=logir,histogram_freq=0, write_graph=True, write_images=False)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

# %%
history = model.fit(train_values, train_classes,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose = 1,
                    validation_data=(test_values,test_classes),
                    callbacks=[tensorboard])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.2192 - accuracy: 0.9335 - val_loss: 0.1276 - val_accuracy: 0.9587
# Epoch 2/20
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0814 - accuracy: 0.9748 - val_loss: 0.0798 - val_accuracy: 0.9756
# Epoch 3/20
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0540 - accuracy: 0.9832 - val_loss: 0.0786 - val_accuracy: 0.9769
# Epoch 4/20
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.0373 - accuracy: 0.9888 - val_loss: 0.0872 - val_accuracy: 0.9792
# Epoch 5/20
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0287 - accuracy: 0.9909 - val_loss: 0.0807 - val_accuracy: 0.9801
# Epoch 6/20
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.0223 - accuracy: 0.9932 - val_loss: 0.0857 - val_accuracy: 0.9814
# Epoch 7/20
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0183 - accuracy: 0.9945 - val_loss: 0.0946 - val_accuracy: 0.9785
# Epoch 8/20
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.0996 - val_accuracy: 0.9834
# Epoch 9/20
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0136 - accuracy: 0.9957 - val_loss: 0.0987 - val_accuracy: 0.9819
# Epoch 10/20
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.0119 - accuracy: 0.9966 - val_loss: 0.1184 - val_accuracy: 0.9798
# Epoch 11/20
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0106 - accuracy: 0.9970 - val_loss: 0.1439 - val_accuracy: 0.9772
# Epoch 12/20
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0096 - accuracy: 0.9970 - val_loss: 0.1259 - val_accuracy: 0.9826
# Epoch 13/20
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0081 - accuracy: 0.9977 - val_loss: 0.1357 - val_accuracy: 0.9813
# Epoch 14/20
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.1292 - val_accuracy: 0.9819
# Epoch 15/20
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0086 - accuracy: 0.9976 - val_loss: 0.1526 - val_accuracy: 0.9826
# Epoch 16/20
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0065 - accuracy: 0.9983 - val_loss: 0.1507 - val_accuracy: 0.9814
# Epoch 17/20
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0061 - accuracy: 0.9984 - val_loss: 0.1819 - val_accuracy: 0.9798
# Epoch 18/20
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0075 - accuracy: 0.9980 - val_loss: 0.1521 - val_accuracy: 0.9840
# Epoch 19/20
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.1780 - val_accuracy: 0.9814
# Epoch 20/20
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.1849 - val_accuracy: 0.9815

# %%
score = model.evaluate(test_values, test_classes, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.1848962453114636
# Test accuracy: 0.9815
