# %% [markdown]
# # Group exercise 2a
# ## Loïc Rosset, Nanae Aubry, Kilian Ruchti, Lionel Ieri

# %% [markdown]
# * Use the provided training set to build your SVM.
# * Apply the trained SVM to classify the test set.
# * Investigate at least two different kernels and optimize the SVM parameters by means of cross-validation.

# %% [markdown]
# ## Import libraries

# %% [markdown]
# Reference :
# * [Cross validation from scikit-learn](https://scikit-learn.org/stable/modules/cross_validation.html)
# * [Grid-Search Cross Validation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html)

# %%
#numpy and panda for data structure
import numpy as np
import pandas as pd
#sklearn for svm and for cross validation
from sklearn import svm
from sklearn import metrics
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Read the provided dataset

# %%
#path to dataset
mnist_train = "./../dataset/csv/mnist_train.csv"
mnist_test = "./../dataset/csv/mnist_test.csv"

# %%
def read_data(filename):
    with open(filename, 'r') as csvfile:
        reader = csv.reader(csvfile)
        data = list(reader)
    #data into numpy array
    matrix = np.array(data, dtype = int)
    samples = matrix[:,1:]
    labels = matrix[:,0]
    return samples, labels

# %%
# Load the training and the test set
training_data, training_labels = read_data(mnist_train)
test_data, test_labels = read_data(mnist_test)

# %% [markdown]
# Computing the following code (section SVM form Scikit-learn) with the whole training dataset takes a while so here is, if needed for testing, a random sample of it :

# %%
random_ids = np.random.randint(0,training_data.shape[0],1000)
sample_data = training_data[random_ids]
sample_labels = training_labels[random_ids]

# %% [markdown]
# ## SVM from Scikit-learn

# %% [markdown]
# Reference : [A practical guide to support vector classification](https://www.csie.ntu.edu.tw/~cjlin/papers/guide/guide.pdf)
#
# SVM trained on a cross-validation of 5 folds and parameters found with Grid-search

# %%
#parameters sequences of C and gamma to be tested
c_seq = [pow(2,x) for x in range(-5, 15, 4)]
gamma_seq = [pow(2,x) for x in range(-15, 3, 4)]

# %%
parameters = {'kernel':('rbf','linear'), 'C':c_seq, 'gamma':gamma_seq}
nb_folds = 4
#Support Vector Classification
svc = svm.SVC()
#Cross-validation
svmOptimized = GridSearchCV(svc, parameters, cv=nb_folds)
svmOptimized.fit(sample_data, sample_labels)
scores = pd.DataFrame.from_dict(svmOptimized.cv_results_)
print("--> Best parameters : ", svmOptimized.best_params_)
scores
# Out:
# --> Best parameters :  {'C': 0.03125, 'gamma': 3.0517578125e-05, 'kernel': 'linear'}
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.876596      0.007425         0.158350        0.004607  0.03125
# 1        0.244249      0.004496         0.095900        0.002548  0.03125
# 2        0.901351      0.006444         0.167331        0.003841  0.03125
# 3        0.243570      0.003364         0.095651        0.000829  0.03125
# 4        0.919993      0.007915         0.163589        0.003580  0.03125
# 5        0.247719      0.009131         0.096783        0.001879  0.03125
# 6        0.902505      0.003064         0.164549        0.004906  0.03125
# 7        0.245843      0.005228         0.095901        0.001581  0.03125
# 8        0.909234      0.004494         0.165506        0.003685  0.03125
# 9        0.252053      0.007090         0.097651        0.002483  0.03125
# 10       0.883840      0.007319         0.154839        0.001868      0.5
# 11       0.249991      0.001917         0.099148        0.004599      0.5
# 12       0.906566      0.003899         0.166579        0.009975      0.5
# 13       0.247893      0.003873         0.098149        0.003485      0.5
# 14       0.931020      0.005297         0.166259        0.005642      0.5
# 15       0.248424      0.006484         0.098148        0.002275      0.5
# 16       0.915552      0.008945         0.162263        0.002215      0.5
# 17       0.245904      0.004268         0.095152        0.001087      0.5
# 18       0.904381      0.002966         0.168268        0.009705      0.5
# 19       0.245562      0.004960         0.096401        0.002685      0.5
# 20       0.905050      0.013091         0.163142        0.011426        8
# 21       0.305316      0.039679         0.116176        0.018690        8
# 22       1.013771      0.108825         0.171380        0.008588        8
# 23       0.313231      0.055660         0.131911        0.032876        8
# 24       0.924979      0.006358         0.166962        0.002720        8
# 25       0.248115      0.004581         0.099653        0.002068        8
# 26       0.932799      0.003596         0.167457        0.004989        8
# 27       0.247722      0.004244         0.098652        0.001600        8
# 28       0.963023      0.077381         0.173580        0.011619        8
# 29       0.248751      0.006006         0.100649        0.003047        8
# 30       0.906363      0.006087         0.159732        0.006925      128
# 31       0.252785      0.006204         0.104229        0.007806      128
# 32       0.951765      0.018008         0.169927        0.004406      128
# 33       0.253240      0.004025         0.097652        0.001089      128
# 34       0.920545      0.007973         0.163462        0.002862      128
# 35       0.258958      0.010716         0.100223        0.004338      128
# 36       0.936826      0.012447         0.161837        0.000998      128
# 37       0.246592      0.003911         0.101046        0.006181      128
# 38       0.924530      0.006099         0.168975        0.009925      128
# 39       0.249170      0.006547         0.098150        0.001087      128
# 40       0.913807      0.020328         0.166942        0.012713     2048
# 41       0.254213      0.005719         0.103143        0.002486     2048
# 42       0.965372      0.020531         0.172692        0.007765     2048
# 43       0.271477      0.036784         0.100927        0.003532     2048
# 44       1.080215      0.199898         0.192860        0.042302     2048
# 45       0.264144      0.015808         0.099647        0.003957     2048
# 46       0.932039      0.011339         0.162786        0.000955     2048
# 47       0.248908      0.005103         0.097579        0.002456     2048
# 48       0.930528      0.004768         0.165789        0.004568     2048
# 49       0.248651      0.005365         0.100619        0.003880     2048
#
#     param_gamma param_kernel  \
# 0   3.05176e-05          rbf
# 1   3.05176e-05       linear
# 2   0.000488281          rbf
# 3   0.000488281       linear
# 4     0.0078125          rbf
# 5     0.0078125       linear
# 6         0.125          rbf
# 7         0.125       linear
# 8             2          rbf
# 9             2       linear
# 10  3.05176e-05          rbf
# 11  3.05176e-05       linear
# 12  0.000488281          rbf
# 13  0.000488281       linear
# 14    0.0078125          rbf
# 15    0.0078125       linear
# 16        0.125          rbf
# 17        0.125       linear
# 18            2          rbf
# 19            2       linear
# 20  3.05176e-05          rbf
# 21  3.05176e-05       linear
# 22  0.000488281          rbf
# 23  0.000488281       linear
# 24    0.0078125          rbf
# 25    0.0078125       linear
# 26        0.125          rbf
# 27        0.125       linear
# 28            2          rbf
# 29            2       linear
# 30  3.05176e-05          rbf
# 31  3.05176e-05       linear
# 32  0.000488281          rbf
# 33  0.000488281       linear
# 34    0.0078125          rbf
# 35    0.0078125       linear
# 36        0.125          rbf
# 37        0.125       linear
# 38            2          rbf
# 39            2       linear
# 40  3.05176e-05          rbf
# 41  3.05176e-05       linear
# 42  0.000488281          rbf
# 43  0.000488281       linear
# 44    0.0078125          rbf
# 45    0.0078125       linear
# 46        0.125          rbf
# 47        0.125       linear
# 48            2          rbf
# 49            2       linear
#
#                                                params  split0_test_score  \
# 0   {'C': 0.03125, 'gamma': 3.0517578125e-05, 'ker...              0.128
# 1   {'C': 0.03125, 'gamma': 3.0517578125e-05, 'ker...              0.888
# 2   {'C': 0.03125, 'gamma': 0.00048828125, 'kernel...              0.128
# 3   {'C': 0.03125, 'gamma': 0.00048828125, 'kernel...              0.888
# 4   {'C': 0.03125, 'gamma': 0.0078125, 'kernel': '...              0.128
# 5   {'C': 0.03125, 'gamma': 0.0078125, 'kernel': '...              0.888
# 6     {'C': 0.03125, 'gamma': 0.125, 'kernel': 'rbf'}              0.128
# 7   {'C': 0.03125, 'gamma': 0.125, 'kernel': 'line...              0.888
# 8         {'C': 0.03125, 'gamma': 2, 'kernel': 'rbf'}              0.128
# 9      {'C': 0.03125, 'gamma': 2, 'kernel': 'linear'}              0.888
# 10  {'C': 0.5, 'gamma': 3.0517578125e-05, 'kernel'...              0.128
# 11  {'C': 0.5, 'gamma': 3.0517578125e-05, 'kernel'...              0.888
# 12  {'C': 0.5, 'gamma': 0.00048828125, 'kernel': '...              0.128
# 13  {'C': 0.5, 'gamma': 0.00048828125, 'kernel': '...              0.888
# 14    {'C': 0.5, 'gamma': 0.0078125, 'kernel': 'rbf'}              0.128
# 15  {'C': 0.5, 'gamma': 0.0078125, 'kernel': 'line...              0.888
# 16        {'C': 0.5, 'gamma': 0.125, 'kernel': 'rbf'}              0.128
# 17     {'C': 0.5, 'gamma': 0.125, 'kernel': 'linear'}              0.888
# 18            {'C': 0.5, 'gamma': 2, 'kernel': 'rbf'}              0.128
# 19         {'C': 0.5, 'gamma': 2, 'kernel': 'linear'}              0.888
# 20  {'C': 8, 'gamma': 3.0517578125e-05, 'kernel': ...              0.128
# 21  {'C': 8, 'gamma': 3.0517578125e-05, 'kernel': ...              0.888
# 22  {'C': 8, 'gamma': 0.00048828125, 'kernel': 'rbf'}              0.128
# 23  {'C': 8, 'gamma': 0.00048828125, 'kernel': 'li...              0.888
# 24      {'C': 8, 'gamma': 0.0078125, 'kernel': 'rbf'}              0.128
# 25   {'C': 8, 'gamma': 0.0078125, 'kernel': 'linear'}              0.888
# 26          {'C': 8, 'gamma': 0.125, 'kernel': 'rbf'}              0.128
# 27       {'C': 8, 'gamma': 0.125, 'kernel': 'linear'}              0.888
# 28              {'C': 8, 'gamma': 2, 'kernel': 'rbf'}              0.128
# 29           {'C': 8, 'gamma': 2, 'kernel': 'linear'}              0.888
# 30  {'C': 128, 'gamma': 3.0517578125e-05, 'kernel'...              0.128
# 31  {'C': 128, 'gamma': 3.0517578125e-05, 'kernel'...              0.888
# 32  {'C': 128, 'gamma': 0.00048828125, 'kernel': '...              0.128
# 33  {'C': 128, 'gamma': 0.00048828125, 'kernel': '...              0.888
# 34    {'C': 128, 'gamma': 0.0078125, 'kernel': 'rbf'}              0.128
# 35  {'C': 128, 'gamma': 0.0078125, 'kernel': 'line...              0.888
# 36        {'C': 128, 'gamma': 0.125, 'kernel': 'rbf'}              0.128
# 37     {'C': 128, 'gamma': 0.125, 'kernel': 'linear'}              0.888
# 38            {'C': 128, 'gamma': 2, 'kernel': 'rbf'}              0.128
# 39         {'C': 128, 'gamma': 2, 'kernel': 'linear'}              0.888
# 40  {'C': 2048, 'gamma': 3.0517578125e-05, 'kernel...              0.128
# 41  {'C': 2048, 'gamma': 3.0517578125e-05, 'kernel...              0.888
# 42  {'C': 2048, 'gamma': 0.00048828125, 'kernel': ...              0.128
# 43  {'C': 2048, 'gamma': 0.00048828125, 'kernel': ...              0.888
# 44   {'C': 2048, 'gamma': 0.0078125, 'kernel': 'rbf'}              0.128
# 45  {'C': 2048, 'gamma': 0.0078125, 'kernel': 'lin...              0.888
# 46       {'C': 2048, 'gamma': 0.125, 'kernel': 'rbf'}              0.128
# 47    {'C': 2048, 'gamma': 0.125, 'kernel': 'linear'}              0.888
# 48           {'C': 2048, 'gamma': 2, 'kernel': 'rbf'}              0.128
# 49        {'C': 2048, 'gamma': 2, 'kernel': 'linear'}              0.888
#
#     split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 0               0.124              0.124              0.124            0.125
# 1               0.868              0.884              0.884            0.881
# 2               0.124              0.124              0.124            0.125
# 3               0.868              0.884              0.884            0.881
# 4               0.124              0.124              0.124            0.125
# 5               0.868              0.884              0.884            0.881
# 6               0.124              0.124              0.124            0.125
# 7               0.868              0.884              0.884            0.881
# 8               0.124              0.124              0.124            0.125
# 9               0.868              0.884              0.884            0.881
# 10              0.124              0.124              0.124            0.125
# 11              0.868              0.884              0.884            0.881
# 12              0.124              0.124              0.124            0.125
# 13              0.868              0.884              0.884            0.881
# 14              0.124              0.124              0.124            0.125
# 15              0.868              0.884              0.884            0.881
# 16              0.124              0.124              0.124            0.125
# 17              0.868              0.884              0.884            0.881
# 18              0.124              0.124              0.124            0.125
# 19              0.868              0.884              0.884            0.881
# 20              0.136              0.140              0.144            0.137
# 21              0.868              0.884              0.884            0.881
# 22              0.136              0.140              0.144            0.137
# 23              0.868              0.884              0.884            0.881
# 24              0.136              0.140              0.144            0.137
# 25              0.868              0.884              0.884            0.881
# 26              0.136              0.140              0.144            0.137
# 27              0.868              0.884              0.884            0.881
# 28              0.136              0.140              0.144            0.137
# 29              0.868              0.884              0.884            0.881
# 30              0.136              0.140              0.144            0.137
# 31              0.868              0.884              0.884            0.881
# 32              0.136              0.140              0.144            0.137
# 33              0.868              0.884              0.884            0.881
# 34              0.136              0.140              0.144            0.137
# 35              0.868              0.884              0.884            0.881
# 36              0.136              0.140              0.144            0.137
# 37              0.868              0.884              0.884            0.881
# 38              0.136              0.140              0.144            0.137
# 39              0.868              0.884              0.884            0.881
# 40              0.136              0.140              0.144            0.137
# 41              0.868              0.884              0.884            0.881
# 42              0.136              0.140              0.144            0.137
# 43              0.868              0.884              0.884            0.881
# 44              0.136              0.140              0.144            0.137
# 45              0.868              0.884              0.884            0.881
# 46              0.136              0.140              0.144            0.137
# 47              0.868              0.884              0.884            0.881
# 48              0.136              0.140              0.144            0.137
# 49              0.868              0.884              0.884            0.881
#
#     std_test_score  rank_test_score
# 0         0.001732               41
# 1         0.007681                1
# 2         0.001732               41
# 3         0.007681                1
# 4         0.001732               41
# 5         0.007681                1
# 6         0.001732               41
# 7         0.007681                1
# 8         0.001732               41
# 9         0.007681                1
# 10        0.001732               41
# 11        0.007681                1
# 12        0.001732               41
# 13        0.007681                1
# 14        0.001732               41
# 15        0.007681                1
# 16        0.001732               41
# 17        0.007681                1
# 18        0.001732               41
# 19        0.007681                1
# 20        0.005916               26
# 21        0.007681                1
# 22        0.005916               26
# 23        0.007681                1
# 24        0.005916               26
# 25        0.007681                1
# 26        0.005916               26
# 27        0.007681                1
# 28        0.005916               26
# 29        0.007681                1
# 30        0.005916               26
# 31        0.007681                1
# 32        0.005916               26
# 33        0.007681                1
# 34        0.005916               26
# 35        0.007681                1
# 36        0.005916               26
# 37        0.007681                1
# 38        0.005916               26
# 39        0.007681                1
# 40        0.005916               26
# 41        0.007681                1
# 42        0.005916               26
# 43        0.007681                1
# 44        0.005916               26
# 45        0.007681                1
# 46        0.005916               26
# 47        0.007681                1
# 48        0.005916               26
# 49        0.007681                1

# %% [markdown]
# ## Classify test set with trained SVM

# %%
labels_pred = svmOptimized.predict(test_data)
print("Accuracy of svm classifier with optimized parameter values: ", metrics.accuracy_score(test_labels, labels_pred)*100,"%")
# Out:
# Accuracy of svm classifier with optimized parameter values:  88.03 %
